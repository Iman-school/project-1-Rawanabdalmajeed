# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic-passengers.csv', sep=';')
df.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin Embarked
# 0      0      248740  13.0000    NaN        S
# 1      0      348123   7.6500  F G73        S
# 2      0      350050   7.8542    NaN        S
# 3      4      349909  21.0750    NaN        S
# 4      0  F.C. 12750  52.0000    B71        S
# 5      0     3101276   7.9250    NaN        S
# 6      0      358585  14.5000    NaN        S
# 7      2        2653  15.7417    NaN        C
# 8      0   A/5 21173   7.2500    NaN        S
# 9      0  SC/AH 3085  26.0000    NaN        S

# %%
def titanic_children(passenger):
    
    age , sex = passenger
    if age <16:
        return 'child'
    else:
        return sex

# %%
df['person'] = df[['Age','Sex']].apply(titanic_children,axis=1)
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
df.head(20)
# Out:
#     PassengerId Survived  Pclass  \
# 0           343       No       2
# 1            76       No       3
# 2           641       No       3
# 3           568       No       3
# 4           672       No       1
# 5           105       No       3
# 6           576       No       3
# 7           382      Yes       3
# 8           228       No       3
# 9           433      Yes       2
# 10          135       No       2
# 11          294       No       3
# 12          755      Yes       2
# 13          595       No       2
# 14          127       No       3
# 15          434       No       3
# 16          378       No       1
# 17          533       No       3
# 18          666       No       2
# 19          225      Yes       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    male  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                              Jensen, Mr. Hans Peder    male  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                              Davidson, Mr. Thornton    male  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                                Patchett, Mr. George    male  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    male  25.0      0
# 11                                Haas, Miss. Aloisia  female  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 13                            Chapman, Mr. John Henry    male  37.0      1
# 14                                McMahon, Mr. Martin    male   NaN      0
# 15                         Kallio, Mr. Nikolai Erland    male  17.0      0
# 16                          Widener, Mr. Harry Elkins    male  27.0      0
# 17                               Elias, Mr. Joseph Jr    male  17.0      1
# 18                                 Hickman, Mr. Lewis    male  32.0      2
# 19                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
#
#     Parch             Ticket      Fare  Cabin Embarked  person
# 0       0             248740   13.0000    NaN        S    male
# 1       0             348123    7.6500  F G73        S    male
# 2       0             350050    7.8542    NaN        S    male
# 3       4             349909   21.0750    NaN        S  female
# 4       0         F.C. 12750   52.0000    B71        S    male
# 5       0            3101276    7.9250    NaN        S    male
# 6       0             358585   14.5000    NaN        S    male
# 7       2               2653   15.7417    NaN        C   child
# 8       0          A/5 21173    7.2500    NaN        S    male
# 9       0         SC/AH 3085   26.0000    NaN        S  female
# 10      0         C.A. 29178   13.0000    NaN        S    male
# 11      0             349236    8.8500    NaN        S  female
# 12      2             220845   65.0000    NaN        S  female
# 13      0        SC/AH 29037   26.0000    NaN        S    male
# 14      0             370372    7.7500    NaN        Q    male
# 15      0  STON/O 2. 3101274    7.1250    NaN        S    male
# 16      2             113503  211.5000    C82        C    male
# 17      1               2690    7.2292    NaN        C    male
# 18      0       S.O.C. 14879   73.5000    NaN        S    male
# 19      0              19943   90.0000    C93        S    male

# %%
df['Alone'] = df.family_size
# if Alone value is >0 then they are with family else they are Alone


df['Alone'].loc[df['Alone']>0] = 'With Family'
df['Alone'].loc[df['Alone'] == 0] = 'Without Family'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14848/1467789292.py in <module>
# ----> 1 df['Alone'] = df.family_size
#       2 # if Alone value is >0 then they are with family else they are Alone
#       3
#       4
#       5 df['Alone'].loc[df['Alone']>0] = 'With Family'
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'family_size'

# %%
df["Survived"].value_counts() #Get a number of who is Survived or not
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
cleanup_Survived = {"Survived":{"No": 0, "Yes": 1}}
df = df.replace(cleanup_Survived) #replace Yes & No with 0 & 1
df.head(10) #print the 1st 5 rows of the data frame
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin Embarked  person
# 0      0      248740  13.0000    NaN        S    male
# 1      0      348123   7.6500  F G73        S    male
# 2      0      350050   7.8542    NaN        S    male
# 3      4      349909  21.0750    NaN        S  female
# 4      0  F.C. 12750  52.0000    B71        S    male
# 5      0     3101276   7.9250    NaN        S    male
# 6      0      358585  14.5000    NaN        S    male
# 7      2        2653  15.7417    NaN        C   child
# 8      0   A/5 21173   7.2500    NaN        S    male
# 9      0  SC/AH 3085  26.0000    NaN        S  female

# %%
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
cleanup_Sex = {"person":     {"female": 0, "male": 1 , "child": 3}}
df = df.replace(cleanup_Sex)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin Embarked  person
# 0      0      248740  13.0000    NaN        S       1
# 1      0      348123   7.6500  F G73        S       1
# 2      0      350050   7.8542    NaN        S       1
# 3      4      349909  21.0750    NaN        S       0
# 4      0  F.C. 12750  52.0000    B71        S       1
# 5      0     3101276   7.9250    NaN        S       1
# 6      0      358585  14.5000    NaN        S       1
# 7      2        2653  15.7417    NaN        C       3
# 8      0   A/5 21173   7.2500    NaN        S       1
# 9      0  SC/AH 3085  26.0000    NaN        S       0

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
cleanup_Embarked = {"Embarked":     {"S": 1, "C": 2 , "Q": 3}}

# %%
df = df.replace(cleanup_Embarked)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin  Embarked  person
# 0      0      248740  13.0000    NaN       1.0       1
# 1      0      348123   7.6500  F G73       1.0       1
# 2      0      350050   7.8542    NaN       1.0       1
# 3      4      349909  21.0750    NaN       1.0       0
# 4      0  F.C. 12750  52.0000    B71       1.0       1
# 5      0     3101276   7.9250    NaN       1.0       1
# 6      0      358585  14.5000    NaN       1.0       1
# 7      2        2653  15.7417    NaN       2.0       3
# 8      0   A/5 21173   7.2500    NaN       1.0       1
# 9      0  SC/AH 3085  26.0000    NaN       1.0       0

# %%
df["Alone"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Alone'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14848/2044517352.py in <module>
# ----> 1 df["Alone"].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Alone'

# %%
cleanup_Alone = {"Alone":     {"With Family": 1, "Alone": 0}}

# %%
df = df.replace(cleanup_Alone)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin  Embarked  person
# 0      0      248740  13.0000    NaN       1.0       1
# 1      0      348123   7.6500  F G73       1.0       1
# 2      0      350050   7.8542    NaN       1.0       1
# 3      4      349909  21.0750    NaN       1.0       0
# 4      0  F.C. 12750  52.0000    B71       1.0       1
# 5      0     3101276   7.9250    NaN       1.0       1
# 6      0      358585  14.5000    NaN       1.0       1
# 7      2        2653  15.7417    NaN       2.0       3
# 8      0   A/5 21173   7.2500    NaN       1.0       1
# 9      0  SC/AH 3085  26.0000    NaN       1.0       0
